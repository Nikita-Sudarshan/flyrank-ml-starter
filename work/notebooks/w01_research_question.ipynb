# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# ## Selected Lane
# Refresh / Content Opportunity Scoring

# ## Why I chose this lane

# I chose the Refresh / Content Opportunity Scoring lane because it focuses on identifying webpages that are most likely to benefit from content updates. Instead of manually reviewing every page, the goal is to prioritize pages based on data-driven evidence so that SEO teams can spend their time on the pages with the highest potential impact.

# This lane uses the starter dataset introduced during Week 1 and provides a clear business objective, making it a practical and achievable capstone project.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# ## Search Question

# Which webpages should be prioritized for content refresh based on historical search performance and engagement signals?

# ## Decision

# Determine which pages should be reviewed first for content updates.

# ## Action

# Generate a ranked refresh queue so that SEO or content teams can update the highest-priority pages before lower-impact pages.

# ## Cost of a Wrong Recommendation

# If high-potential pages are ranked too low, valuable traffic opportunities may be missed.

# If healthy pages are incorrectly recommended for refresh, time and resources may be spent on pages that do not require updates.

# ## Why Machine Learning?

# Multiple signals such as impressions, click-through rate, search volume, position, and engagement interact with each other. Machine learning can identify patterns across these features that are difficult to capture using simple rule-based methods.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import subprocess

if not os.path.exists("flyrank-ml-starter"):
    # !git clone https://github.com/Nikita-Sudarshan/flyrank-ml-starter.git

os.chdir("flyrank-ml-starter")

print("Current directory:", os.getcwd())

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Total Pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 4))
print("Median Word Count:", int(df["word_count"].median()))

print("\nTrend Direction Distribution:")
print(df["trend_direction"].value_counts())
# ## Observations

# The starter dataset contains 30,000 webpages with multiple SEO and engagement-related features.

# The average click-through rate provides an overview of overall user engagement, while the median word count helps describe the typical content length.

# These statistics indicate that the dataset contains enough variation to support prioritizing refresh opportunities using data-driven methods.
# Out:
# Cloning into 'flyrank-ml-starter'...
# remote: Enumerating objects: 113, done.
# remote: Counting objects: 100% (113/113), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 113 (delta 28), reused 80 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (113/113), 1.87 MiB | 5.71 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# Current directory: /content/flyrank-ml-starter/flyrank-ml-starter/flyrank-ml-starter
# Rows: 30000
# Columns: 44
# Total Pages: 30000
# Average CTR: 0.5107
# Median Word Count: 2877
#
# Trend Direction Distribution:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# The analysis in this notebook identifies patterns within the available dataset.

# The results should be treated as evidence to support decision-making rather than proof of how search engines rank webpages.

# Recommendations should be validated alongside domain knowledge before implementation.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
